# %% [raw]
# ---
# description: Module for computing digitally reconstructed radiographs
# output-file: drr.html
# title: DRR
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(DRR)
# Out:
# /Users/vivek/mambaforge/envs/nbdev-diffdrr/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Inputs
#   else: warn(msg)
# ---
#
# [source](https://github.com/eigenvivek/DiffDRR/blob/main/diffdrr/drr.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### DRR
#
# >      DRR (volume, spacing, height, delx, width=None, dely=None,
# >           p_subsample=None, reshape=True, params=None, dtype=None,
# >           device=None, projector=None)
#
# Class for generating DRRs.
