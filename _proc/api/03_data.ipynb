# %% [raw]
# ---
# description: Load example datasets
# output-file: data.html
# title: data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(read_dicom)
# Out:
# /Users/vivek/mambaforge/envs/nbdev-diffdrr/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Inputs
# ----- in
# Inputs
# -----...
#   else: warn(msg)
# ---
#
# [source](https://github.com/eigenvivek/DiffDRR/blob/main/diffdrr/data.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### read_dicom
#
# >      read_dicom (dcmdir, correct_zero=True)
#
# Inputs
# -----
# dcmdir : Path or str
#     Path to a DICOM directory
# correct_zero : bool
#     Make 0 the minimum value the CT
# Returns
# -------
# volume : ndarray
#     3D array containing voxels of imaging data
# spacing : list
#     X-, Y-, and Z-directional voxel spacings

# %%
#| echo: false
#| output: asis
show_doc(load_example_ct)
# Out:
# ---
#
# [source](https://github.com/eigenvivek/DiffDRR/blob/main/diffdrr/data.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_example_ct
#
# >      load_example_ct ()
#
# Load an example chest CT for demonstration purposes.
