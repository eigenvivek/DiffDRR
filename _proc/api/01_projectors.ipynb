# %% [raw]
# ---
# description: Mapping from ray to pixel intensity
# output-file: projectors.html
# title: projectors
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(siddon_raycast)
# Out:
# ---
#
# [source](https://github.com/eigenvivek/DiffDRR/blob/main/diffdrr/projectors.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### siddon_raycast
#
# >      siddon_raycast (source, target, volume, spacing, eps=1e-08)
