# %% [raw]
# ---
# description: Set up the 7 degrees-of-freedom parameters for the C-arm
# output-file: camera.html
# title: camera
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Detector)
# Out:
# ---
#
# [source](https://github.com/eigenvivek/DiffDRR/blob/main/diffdrr/camera.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### Detector
#
# >      Detector (height, width, delx, dely, n_subsample)
#
# Construct a 6 DoF X-ray detector system. This model is based on a C-Arm.
# Inputs
# ------
# height : int
#     Height of the X-ray detector (ie, DRR height)
# width : int
#     Width of the X-ray detector (ie, DRR width)
# delx : float
#     Pixel spacing in the X-direction of the X-ray detector
# dely : float
#     Pixel spacing in the Y-direction of the X-ray detector
# n_subsample : int
#     Number of target points to randomly sample
