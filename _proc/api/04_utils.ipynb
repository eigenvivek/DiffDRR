# %% [raw]
# ---
# description: Utility functions
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(reshape_subsampled_drr)
# Out:
# ---
#
# [source](https://github.com/eigenvivek/DiffDRR/blob/main/diffdrr/utils.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### reshape_subsampled_drr
#
# >      reshape_subsampled_drr (img, detector, batch_size)
